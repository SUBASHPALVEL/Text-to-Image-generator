# %% [markdown]
# DALL .E. 2 Mini is a new AI system that can create realistic images and art from a description in natural language.

# %%
# !pip install min-dalle -q
# Out:
#      |████████████████████████████████| 240 kB 6.7 MB/s
# ...

# %%
from min_dalle import MinDalle
model = MinDalle(is_mega=True, is_reusable=True)
# Out:
# using device cuda
# downloading tokenizer params
# intializing TextTokenizer
# downloading encoder params
# initializing DalleBartEncoder
# downloading decoder params
# initializing DalleBartDecoder
# downloading detokenizer params
# initializing VQGanDetokenizer

# %%
# %%time
text="cat is fighting with a dog"
seed = 6
grid_size =2

display(model.generate_image(text,seed,grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FAD6A1DDB50>
# CPU times: user 31.7 s, sys: 1.14 s, total: 32.8 s
# Wall time: 37.3 s

# %%
# %%time
text="polar bear playing guitar"
seed = 6
grid_size =2

display(model.generate_image(text,seed,grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA9A9BE7910>
# CPU times: user 31.4 s, sys: 632 ms, total: 32 s
# Wall time: 32 s

# %%
# %%time
text="IEEE Women in Engineering Chapter"
seed = 6
grid_size =2

display(model.generate_image(text,seed,grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FAD602F8F10>
# CPU times: user 31.2 s, sys: 532 ms, total: 31.8 s
# Wall time: 31.7 s

# %%
# %%time
text1="drummer singing a song in kolkata"
seed = 6
grid_size = 2

display(model.generate_image(text1, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA9A9BD3550>
# CPU times: user 30.6 s, sys: 550 ms, total: 31.2 s
# Wall time: 31.4 s

# %%
# %%time
text2="There are dolphins in the sea"
seed = 6
grid_size = 2

display(model.generate_image(text2, seed, grid_size))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FA9A9BCF450>
# CPU times: user 31 s, sys: 538 ms, total: 31.6 s
# Wall time: 31.5 s
